# %%
import requests
import random
from secret import API_KEY, CITY_ID, CITY_NAME, ACCOUNT_SID, AUTH_TOKEN, SHAWTY_BAES_NUMBER, MY_TWILIO_NUMBER, CONFIRMATION_NUMBER, LATITUDE, LONGITUDE
from main import send_message, select_quote_and_name
from twilio.rest import Client
import time
from time import strftime, localtime

# %%
url: str = f"https://api.openweathermap.org/data/2.5/forecast?lat={LATITUDE}&lon={LONGITUDE}&appid={API_KEY}"
data = requests.get(url).json()

# %% [markdown]
# ##### First indexing into list of weather by 3-hour stamps and then getting the ids, the idea is to iterate through the enough 3-hour stamps to cover the whole length of her day as opposed to just checkng the weather at one given point in time in my case which was early in the morning

# %%
data['list'][:10]
# Out:
# [{'dt': 1685728800,
#   'main': {'temp': 300.57,
#    'feels_like': 300.84,
#    'temp_min': 297.17,
#    'temp_max': 300.57,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 997,
#    'humidity': 48,
#    'temp_kf': 3.4},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 20},
#   'wind': {'speed': 2.94, 'deg': 8, 'gust': 3.63},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-06-02 18:00:00'},
#  {'dt': 1685739600,
#   'main': {'temp': 299.77,
#    'feels_like': 299.77,
#    'temp_min': 298.18,
#    'temp_max': 299.77,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 996,
#    'humidity': 53,
#    'temp_kf': 1.59},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 25},
#   'wind': {'speed': 3.62, 'deg': 333, 'gust': 4.83},
#   'visibility': 10000,
#   'pop': 0.33,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-06-02 21:00:00'},
#  {'dt': 1685750400,
#   'main': {'temp': 294.96,
#    'feels_like': 295,
#    'temp_min': 292.16,
#    'temp_max': 294.96,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 996,
#    'humidity': 69,
#    'temp_kf': 2.8},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 46},
#   'wind': {'speed': 3.66, 'deg': 3, 'gust': 9.58},
#   'visibility': 10000,
#   'pop': 0.56,
#   'rain': {'3h': 0.37},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-06-03 00:00:00'},
#  {'dt': 1685761200,
#   'main': {'temp': 289.91,
#    'feels_like': 290.07,
#    'temp_min': 289.91,
#    'temp_max': 289.91,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 996,
#    'humidity': 93,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.74, 'deg': 324, 'gust': 6.78},
#   'visibility': 10000,
#   'pop': 0.81,
#   'rain': {'3h': 1.21},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-06-03 03:00:00'},
#  {'dt': 1685772000,
#   'main': {'temp': 289.44,
#    'feels_like': 289.68,
#    'temp_min': 289.44,
#    'temp_max': 289.44,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 996,
#    'humidity': 98,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.74, 'deg': 321, 'gust': 2.77},
#   'visibility': 10000,
#   'pop': 0.96,
#   'rain': {'3h': 2.51},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-06-03 06:00:00'},
#  {'dt': 1685782800,
#   'main': {'temp': 288.06,
#    'feels_like': 288.14,
#    'temp_min': 288.06,
#    'temp_max': 288.06,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 996,
#    'humidity': 97,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 5.44, 'deg': 45, 'gust': 11.07},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-06-03 09:00:00'},
#  {'dt': 1685793600,
#   'main': {'temp': 286.95,
#    'feels_like': 286.76,
#    'temp_min': 286.95,
#    'temp_max': 286.95,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 999,
#    'humidity': 91,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 95},
#   'wind': {'speed': 6.45, 'deg': 49, 'gust': 12.49},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-06-03 12:00:00'},
#  {'dt': 1685804400,
#   'main': {'temp': 287.94,
#    'feels_like': 287.62,
#    'temp_min': 287.94,
#    'temp_max': 287.94,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1000,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 93},
#   'wind': {'speed': 7.58, 'deg': 48, 'gust': 10.89},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-06-03 15:00:00'},
#  {'dt': 1685815200,
#   'main': {'temp': 291.08,
#    'feels_like': 290.63,
#    'temp_min': 291.08,
#    'temp_max': 291.08,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1000,
#    'humidity': 65,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 72},
#   'wind': {'speed': 8.15, 'deg': 43, 'gust': 11.81},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-06-03 18:00:00'},
#  {'dt': 1685826000,
#   'main': {'temp': 291.03,
#    'feels_like': 290.31,
#    'temp_min': 291.03,
#    'temp_max': 291.03,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1000,
#    'humidity': 55,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 3},
#   'wind': {'speed': 8.42, 'deg': 42, 'gust': 13.22},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-06-03 21:00:00'}]

# %%
data['list'][0]['weather'][0]
# Out:
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}

# %%
is_rainy = False
for i in range(5):
    if data['list'][i]['weather'][0]['id'] < 600:
        is_rainy = True
        forecast = data['list'][i]['weather'][0]['main']
    

    print(strftime('%Y-%m-%d %H:%M:%S', localtime(data["list"][i]["dt"])))
# Out:
# 2023-06-02 14:00:00
# 2023-06-02 17:00:00
# 2023-06-02 20:00:00
# 2023-06-02 23:00:00
# 2023-06-03 02:00:00
# 2023-06-03 05:00:00
